# %% [markdown]
# <a href="https://colab.research.google.com/github/nanasita2002/portfolio/blob/main/%D0%9E%D0%B1%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%BA%D0%B0%20%D0%B2%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown --quiet

import gdown
import pandas as pd

url_prolongations = 'https://drive.google.com/uc?id=1n2CIsPZYOIqMfV7b3aUtp1efc9U96xVt'
url_financial = 'https://drive.google.com/uc?id=1r3grFMz_k-XuWhRNLOAZCoLDdVYg2C7X'

# Скачиваем файлы
print("Скачиваем файл 1...")
gdown.download(url_prolongations, 'prolongations.csv')

print("\nСкачиваем файл 2...")
gdown.download(url_financial, 'financial_data.csv')

print("\n Файлы успешно скачаны.")

# Загрузка данных в DataFrame
try:
    prolongations_df = pd.read_csv('prolongations.csv', sep=';', encoding='utf-8')
    financial_df = pd.read_csv('financial_data.csv', sep=';', encoding='utf-8', skipinitialspace=True)

    print(prolongations_df.head())
    print("\n")
    print(financial_df.head())

except Exception as e:
    print("\n Ошибка")
# Out:
# Скачиваем файл 1...
# Downloading...
# From: https://drive.google.com/uc?id=1n2CIsPZYOIqMfV7b3aUtp1efc9U96xVt
# To: /content/prolongations.csv
# 100%|██████████| 35.7k/35.7k [00:00<00:00, 41.9MB/s]
# Скачиваем файл 2...
# Downloading...
# From: https://drive.google.com/uc?id=1r3grFMz_k-XuWhRNLOAZCoLDdVYg2C7X
# To: /content/financial_data.csv
# 100%|██████████| 74.3k/74.3k [00:00<00:00, 3.29MB/s]
# ✅ Файлы успешно скачаны.
#                                      id,month,AM
# 0    42,ноябрь 2022,Васильев Артем Александрович
# 1   453,ноябрь 2022,Васильев Артем Александрович
# 2      548,ноябрь 2022,Михайлов Андрей Сергеевич
# 3   87,ноябрь 2022,Соколова Анастасия Викторовна
# 4  429,ноябрь 2022,Соколова Анастасия Викторовна
#
#
#   id,Причина дубля,Ноябрь 2022,Декабрь 2022,Январь 2023,Февраль 2023,Март 2023,Апрель 2023,Май 2023,Июнь 2023,Июль 2023,Август 2023,Сентябрь 2023,Октябрь 2023,Ноябрь 2023,Декабрь 2023,Январь 2024,Февраль 2024,Account
# 0  42,,"36 220,00",,,,,,,,,,,,,,,,Васильев Артем ...
# 1  657,первая часть оплаты,стоп,,,,,,,,,,,,,,,,Ва...
# 2  657,вторая часть оплаты,стоп,,,,,,,,,,,,,,,,Ва...
# 3  594,,стоп,,,,,,,,,,,,,,,,Васильев Артем Алекса...
# 4  665,,"10 000,00",,,,,,,,,,,,,,,,Васильев Артем...
